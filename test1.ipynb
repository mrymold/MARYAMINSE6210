# %% [markdown]
# <a href="https://colab.research.google.com/github/mrymold/MARYAMINSE6210/blob/main/test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# this a lab 01

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/spotify_weekly_chart.csv')
df.head(10)
# Out:
#    Pos  P+            Artist                                  Title  Wks  Pk  \
# 0    1   =              SZA                               Kill Bill    5   1
# 1    2  +3     Metro Boomin                                Creepin'    6   2
# 2    3  -1        Sam Smith                                  Unholy   16   1
# 3    4  -1     Harry Styles                               As It Was   41   1
# 4    5  -1     David Guetta                         I'm Good (Blue)   20   2
# 5    6   =    Manuel Turizo                              La Bachata   28   4
# 6    7   =     Taylor Swift                                    Anti   12   1
# 7    8  +1         Arcángel                                La Jumpa    6   8
# 8    9  -1         Bizarrap   Quevedo: Bzrp Music Sessions, Vol. 52   27   1
# 9   10  +1  Stephen Sanchez                       Until I Found You    6  10
#
#     (x?)   Streams   Streams+       Total
# 0   (x2)  47288509  5814143.0   208044297
# ...

# %%
df['Title']
# Out:
# 0              Kill Bill
# 1               Creepin'
# 2                 Unholy
# 3              As It Was
# 4        I'm Good (Blue)
#              ...
# 195         Boy's a liar
# 196             Kesariya
# 197    Take Me To Church
# 198       Agudo Mágico 3
# 199             Payphone
# Name: Title, Length: 200, dtype: object

# %%
df['Wks']
# Out:
# 0        5
# 1        6
# 2       16
# 3       41
# 4       20
#       ...
# 195      1
# 196     11
# 197    202
# 198      1
# 199     50
# Name: Wks, Length: 200, dtype: int64

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c976c8f2-85a5-4081-b2bf-e4b8504c6cbc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c976c8f2-85a5-4081-b2bf-e4b8504c6cbc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df2=pd.read_csv('/content/Iris.csv')
df2.head(20)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
df2['Id']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 145    146
# 146    147
# 147    148
# 148    149
# 149    150
# Name: Id, Length: 150, dtype: int64

# %%
df2.shape
# Out:
# (150, 6)

# %%
df3=pd.read_csv('/content/drive/MyDrive/6220/spotify_weekly_chart.csv') 
df3.tail(10)
# Out:
#      Pos   P+            Artist                              Title  Wks   Pk  \
# 190  191  -14          Shakira                         Te Felicito   35   13
# 191  192   RE         Coldplay                         My Universe   63    3
# 192  193  -11     Taylor Swift             You're On Your Own, Kid   11    6
# 193  194   RE     Taylor Swift                      Don’t Blame Me   28   72
# 194  195   -1  Tears For Fears   Everybody Wants To Rule The World   24  105
# 195  196  NEW   PinkPantheress                        Boy's a liar    1  196
# 196  197   -8           Pritam                            Kesariya   11   71
# 197  198   RE           Hozier                   Take Me To Church  202    1
# 198  199  NEW           MC K.K                      Agudo Mágico 3    1  199
# 199  200   RE         Maroon 5                            Payphone   50   70
#
#      (x?)  Streams  Streams+       Total
# 190   NaN  6823173 -262572.0   424378574
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
